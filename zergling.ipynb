# %%
from scboy.starter import zealot

cmd = 'price test'

df = zealot(cmd)

df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>open</th>
#       <th>high</th>
#       <th>low</th>
#       <th>close</th>
#     </tr>
#     <tr>
#       <th>date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>03/01/2005 17:00</th>
#       <td>1.35316</td>
#       <td>1.35796</td>
#       <td>1.33866</td>
#       <td>1.34646</td>
#     </tr>
#     <tr>
#       <th>04/01/2005 17:00</th>
#       <td>1.34646</td>
#       <td>1.34946</td>
#       <td>1.32496</td>
#       <td>1.32706</td>
#     </tr>
#     <tr>
#       <th>05/01/2005 17:00</th>
#       <td>1.32706</td>
# ...
